# %% [markdown]
# # Atividade Prática — Aula 2: Pandas Essencial
#
# Nesta atividade, você vai aplicar os conceitos da aula para explorar um dataset de vendas, fazer um **check-up inicial**, selecionar colunas relevantes, criar **filtros de negócio**, construir **rankings** e transformar resultados em **interpretação gerencial**.
#
# **Dataset:** `vendas_dataviz_aula2.csv`
#
# ## Objetivos da atividade
# - Ler e inspecionar um dataset com Pandas
# - Entender a diferença entre DataFrame e Series
# - Verificar tamanho, tipos e possíveis problemas de qualidade
# - Selecionar apenas as colunas importantes para análise
# - Filtrar dados com uma e múltiplas condições
# - Criar rankings com `sort_values`, `nlargest` e `nsmallest`
# - Interpretar resultados em linguagem de negócio

# %% [markdown]
# ## 1. Importação das bibliotecas
#
# Importe as bibliotecas necessárias para a atividade.
# - `pandas`
# - `numpy`
# - `matplotlib.pyplot` (caso queira visualizar resultados)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from cycler import cycler
meu_ciclo=cycler('color',plt.get_cmap('Set1').colors)
plt.rc('axes',prop_cycle=meu_ciclo)

# %% [markdown]
# ## 2. Leitura do dataset
#
# Leia o arquivo `vendas_dataviz_aula2.csv` em um DataFrame chamado `df`.
# Depois, exiba as 5 primeiras linhas.

# %%
df = pd.read_csv('../datasets/vendas_dataviz_aula2.csv')
df.head()
# Out:
#          data           produto    categoria estado        canal   vendas  \
# 0  2024-04-12       Mouse Gamer  Periféricos     RJ  Marketplace   562.26
# 1  2024-05-01           Headset        Áudio     ES  MarketPlace  1124.08
# 2  2024-10-03  Teclado Mecânico  Periféricos     SP  Marketplace  2515.73
# 3  2024-07-06         Webcam HD  Periféricos     SP  Marketplace   596.76
# 4  2024-02-24        Smartwatch    Telefonia     RJ  Loja Física  3908.08
#
#    quantidade  preco_unitario   custo    lucro  avaliacao_cliente
# 0           3          187.42   97.70   269.16                4.6
# 1           4          281.02  144.77   545.00                3.8
# 2           7          359.39  153.66  1440.11                4.3
# 3           3          198.92  125.09   221.49                4.3
# 4           4          977.02  666.26  1243.04                4.4

# %%
df.tail()
# Out:
#            data           produto    categoria estado        canal    vendas  \
# 445  2024-12-19       Tablet Plus    Telefonia     ES  Loja Física   4514.46
# 446  2024-08-28      Smartphone X    Telefonia     MG  Marketplace   8410.32
# 447  2024-12-08      Notebook Pro  Informática     BA  Loja Física  15057.27
# 448  2024-11-15  Teclado Mecânico  Periféricos     GO       Online    936.66
# 449  2024-06-10  Teclado Mecânico  Periféricos     SP  Marketplace   1818.06
#
#      quantidade  preco_unitario    custo    lucro  avaliacao_cliente
# 445           2         2257.23  1469.07  1576.32                3.9
# 446           3         2803.44  2220.34  1749.30                3.5
# 447           3         5019.09  3189.24  5489.55                3.9
# 448           3          312.22   165.46   440.28                3.8
# 449           6          303.01   178.28      inf                4.4

# %% [markdown]
# ## 3. Anatomia dos dados: DataFrame e Series
#
# ### Questão 1
# Explique, com base no que foi visto em aula:
# 1. O que é um **DataFrame**?
#  R:Um Tipo de objeto python que se parece muito com uma tabela de excel.
# 2. O que é uma **Series**?
# R: É uma coluna de um DataFrame
# 3. Mostre no código uma coluna isolada do DataFrame.

# %%
# Exemplo: selecione uma única coluna e observe o tipo retornado
serie_produto = df['produto']
type(serie_produto), serie_produto.head()
# Out:
# (pandas.Series,
#  0         Mouse Gamer
#  1             Headset
#  2    Teclado Mecânico
#  3           Webcam HD
#  4          Smartwatch
#  Name: produto, dtype: str)

# %% [markdown]
# ## 4. Check-up inicial do dataset
#
# Um analista profissional sempre começa verificando o tamanho, a estrutura e a qualidade inicial dos dados.
#
# ### Questão 2
# Use:
# - `df.shape`
# - `df.info()`
# - `df.dtypes`
#
# Depois responda:
# 1. Quantas linhas e colunas existem? R:450
# 2. Quais colunas parecem numéricas? R:5
# 3. Há sinais de valores ausentes? R: Sim, nas colunas avaliacao cliente e estado
# 4. Existe alguma coluna com tipo inadequado?R: Coluna Data

# %%
df.shape
# Out:
# (450, 11)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   data               450 non-null    str
#  1   produto            450 non-null    str
#  2   categoria          450 non-null    str
#  3   estado             449 non-null    str
#  4   canal              450 non-null    str
#  5   vendas             450 non-null    str
#  6   quantidade         450 non-null    int64
#  7   preco_unitario     450 non-null    float64
#  8   custo              450 non-null    float64
#  9   lucro              450 non-null    float64
#  10  avaliacao_cliente  448 non-null    float64
# dtypes: float64(4), int64(1), str(6)
# memory usage: 38.8 KB

# %%
df['data'] = pd.to_datetime(df['data'])

# %%
df['receita'] = df['custo'] + df['lucro']

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# avaliacao_cliente    2
# estado               1
# produto              0
# data                 0
# categoria            0
# canal                0
# quantidade           0
# vendas               0
# preco_unitario       0
# custo                0
# lucro                0
# receita              0
# dtype: int64

# %%
df['vendas'].sample(50)
# Out:
# 426     1887.44
# 135      1824.7
# 272     1109.36
# 106     1861.06
# 2       2515.73
# 299       819.3
# 72       8142.3
# 384     7788.69
# 240      6039.0
# 324       887.7
# 18       278.57
# 378      187.61
# 46      1241.04
# 428      1309.3
# 9       3810.69
# 25      7614.66
# 427     1033.35
# 286     1626.12
# 397     6702.78
# 379       771.8
# 51       9516.4
# 156      532.05
# 176     2963.42
# 318     1214.76
# 75       231.89
# 392       354.4
# 24      8343.45
# 351      720.52
# 434      1932.2
# 152      1520.3
# 56     27867.72
# 58      10662.2
# 230     5628.04
# 169     6014.22
# 308     3115.26
# 168      255.29
# 211      3305.2
# 233      484.56
# 423     4294.12
# 232     2515.52
# 300     4403.16
# 87       2398.5
# 197     2744.94
# 151      1654.7
# 363     2563.35
# 50       1964.2
# 420     1114.84
# 170      832.44
# 120     2433.12
# 174      843.24
# Name: vendas, dtype: str

# %%
dados_com_problemas = []

for venda in df['vendas']:
    try:
        float(venda)
    except:
        dados_com_problemas.append(venda)

# %%
dados_com_problemas
# Out:
# ['R$ 801,60', 'R$ 787,17', 'R$ 663,80']

# %%
df['vendas'].apply(lambda x: x.replace('R$ ','').replace(",",'.'))
# Out:
# 0        562.26
# 1       1124.08
# 2       2515.73
# 3        596.76
# 4       3908.08
#          ...
# 445     4514.46
# 446     8410.32
# 447    15057.27
# 448      936.66
# 449     1818.06
# Name: vendas, Length: 450, dtype: str

# %%
df['vendas'].head()
# Out:
# 0     562.26
# 1    1124.08
# 2    2515.73
# 3     596.76
# 4    3908.08
# Name: vendas, dtype: str

# %%
df['vendas'] = pd.to_numeric(df['vendas'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   data               450 non-null    datetime64[us]
#  1   produto            450 non-null    str
#  2   categoria          450 non-null    str
#  3   estado             449 non-null    str
#  4   canal              450 non-null    str
#  5   vendas             447 non-null    float64
#  6   quantidade         450 non-null    int64
#  7   preco_unitario     450 non-null    float64
#  8   custo              450 non-null    float64
#  9   lucro              450 non-null    float64
#  10  avaliacao_cliente  448 non-null    float64
#  11  receita            450 non-null    float64
# dtypes: datetime64[us](1), float64(6), int64(1), str(4)
# memory usage: 42.3 KB

# %%
df.isna().sum()
# Out:
# data                 0
# produto              0
# categoria            0
# estado               1
# canal                0
# vendas               3
# quantidade           0
# preco_unitario       0
# custo                0
# lucro                0
# avaliacao_cliente    2
# receita              0
# dtype: int64

# %%
df = df.dropna()

# %%
colunas_categoricas=df.select_dtypes(exclude='number').drop(columns='data').columns
colunas_categoricas
# Out:
# Index(['produto', 'categoria', 'estado', 'canal'], dtype='str')

# %%
for col in colunas_categoricas:
    print(df[col].unique())
# Out:
# <StringArray>
# [     'Mouse Gamer',          'Headset', 'Teclado Mecânico',
#         'Webcam HD',       'Smartwatch',     'Caixa de Som',
#      'Notebook Pro',      'Tablet Plus',       'Monitor 27',
#      'Smartphone X']
# Length: 10, dtype: str
# <StringArray>
# ['Periféricos', 'Áudio', 'Telefonia', 'Informática']
# Length: 4, dtype: str
# <StringArray>
# ['RJ', 'ES', 'SP', 'PE', 'SC', 'MG', 'PR', 'BA', 'GO', 'RS', 'rj']
# Length: 11, dtype: str
# <StringArray>
# ['Marketplace', 'MarketPlace', 'Loja Física', 'Online', 'online', 'ONLINE']
# Length: 6, dtype: str

# %%
df['estado'] = df['estado'].str.replace('rj','RJ')
df['canal'] = df['canal'].str.replace('MarketPlace','Marketplace')
df['canal'] = df['canal'].str.replace('online','Online')
df['canal'] = df['canal'].str.capitalize()

# %% [markdown]
# ## 5. Inspeção de problemas de qualidade
#
# Na aula, vimos que dashboards podem falhar por causa de dados mal preparados.
#
# ### Questão 3
# Investigue:
# - valores nulos
# - categorias inconsistentes
# - números armazenados como texto
# - valores infinitos
#
# Dica:
# - `df.isna().sum()`
# - `df['canal'].value_counts(dropna=False)`
# - `df['estado'].value_counts(dropna=False)`
# - `np.isinf(...)`

# %%
df['canal'].value_counts(dropna=False)
# Out:
# canal
# Marketplace    151
# Online         147
# Loja física    146
# Name: count, dtype: int64

# %%
df['estado'].value_counts(dropna=False)
# Out:
# estado
# ES    62
# BA    52
# SP    51
# GO    49
# PE    48
# SC    42
# MG    38
# RS    37
# RJ    35
# PR    30
# Name: count, dtype: int64

# %%
df.describe(include='number').T
# Out:
# /home/aronfb/workspace/analise-de-dados/linguagens-de-programacao/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1020: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/aronfb/workspace/analise-de-dados/linguagens-de-programacao/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1020: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#                    count         mean          std     min       25%  \
# vendas             444.0  4276.823986  5206.362607  158.60  931.9500
# quantidade         444.0     3.878378     2.058639    1.00    2.0000
# preco_unitario     444.0  1168.562117  1259.031994  148.43  263.4425
# custo              444.0   822.663604   939.336711   80.12  147.4375
# lucro              444.0          inf          NaN   60.58  380.7650
# avaliacao_cliente  444.0     4.087162     0.459504    2.70    3.8000
# receita            444.0          inf          NaN  158.60  574.6700
#
#                         50%        75%       max
# vendas             1821.380  6100.6925  36140.72
# quantidade            4.000     5.0000     11.00
# preco_unitario      400.745  1987.8700   5088.24
# custo               234.725  1438.0000   3437.34
# lucro               707.010  1620.6475       inf
# avaliacao_cliente     4.100     4.4000      5.00
# receita            1061.050  3086.4300       inf

# %%
df['lucro'] = pd.to_numeric(df['lucro'],errors='coerce')

# %%
df['lucro'].sort_values(ascending=False)
# Out:
# 449         inf
# 199         inf
# 183    13556.90
# 321    10319.12
# 56      9411.00
#          ...
# 143       77.72
# 42        74.89
# 48        71.29
# 273       65.92
# 415       60.58
# Name: lucro, Length: 444, dtype: float64

# %%
df.sample(30)
# Out:
#           data           produto    categoria estado        canal    vendas  \
# 17  2024-08-18        Smartwatch    Telefonia     SP  Marketplace   7284.88
# 58  2024-01-16      Smartphone X    Telefonia     BA  Loja física  10662.20
# 446 2024-08-28      Smartphone X    Telefonia     MG  Marketplace   8410.32
# 224 2024-07-31      Caixa de Som        Áudio     PR       Online   2086.20
# 417 2024-12-08       Mouse Gamer  Periféricos     SC  Loja física    172.19
# 94  2024-11-30        Smartwatch    Telefonia     BA       Online   6760.88
# 203 2024-06-05       Mouse Gamer  Periféricos     MG  Loja física    864.40
# 27  2024-08-27  Teclado Mecânico  Periféricos     GO  Marketplace    989.04
# 269 2024-08-28         Webcam HD  Periféricos     GO       Online   1052.48
# 323 2024-01-20           Headset        Áudio     PE  Loja física    250.90
# 279 2024-12-26           Headset        Áudio     ES       Online    270.57
# 253 2024-10-26      Smartphone X    Telefonia     ES  Loja física   2680.58
# 426 2024-08-03           Headset        Áudio     SC  Loja física   1887.44
# 114 2024-10-26       Mouse Gamer  Periféricos     RJ       Online    378.40
# 197 2024-12-19      Caixa de Som        Áudio     RS       Online   2744.94
# 322 2024-03-26       Tablet Plus    Telefonia     PE  Loja física   8558.88
# 134 2024-02-20      Caixa de Som        Áudio     GO  Marketplace   1179.36
# 381 2024-09-24      Smartphone X    Telefonia     RJ       Online  12241.04
# 12  2024-09-17  Teclado Mecânico  Periféricos     ES       Online   1005.84
# 76  2024-05-27      Caixa de Som        Áudio     ES  Marketplace   2484.30
# 261 2024-06-21      Notebook Pro  Informática     GO  Loja física  16987.12
# 449 2024-06-10  Teclado Mecânico  Periféricos     SP  Marketplace   1818.06
# 179 2024-12-24       Mouse Gamer  Periféricos     BA  Marketplace   1459.44
# 42  2024-09-12       Mouse Gamer  Periféricos     RJ  Loja física    176.14
# 56  2024-09-06      Notebook Pro  Informática     PE       Online  27867.72
# 148 2024-09-11       Mouse Gamer  Periféricos     SC  Loja física    374.10
# 9   2024-12-03      Caixa de Som        Áudio     PE       Online   3810.69
# 229 2024-03-27       Mouse Gamer  Periféricos     RJ  Loja física    401.60
# 190 2024-12-14         Webcam HD  Periféricos     RS  Loja física   1282.85
# 26  2024-05-02           Headset        Áudio     SP  Marketplace   1482.72
#
#      quantidade  preco_unitario    custo    lucro  avaliacao_cliente   receita
# 17            8          910.61   618.47  2337.12                3.8   2955.59
# 58            4         2665.55  2108.80  2227.00                3.8   4335.80
# 446           3         2803.44  2220.34  1749.30                3.5   3969.64
# 224           5          417.24   204.27  1064.85                3.8   1269.12
# 417           1          172.19    90.51    81.68                3.7    172.19
# 94            8          845.11   583.57  2092.32                4.2   2675.89
# 203           5          172.88    90.88   410.00                4.3    500.88
# 27            3          329.68   200.89   386.37                4.0    587.26
# 269           4          263.12   135.31   511.24                4.1    646.55
# 323           1          250.90   156.50    94.40                3.8    250.90
# 279           1          270.57   140.07   130.50                3.2    270.57
# 253           1         2680.58  2304.67   375.91                4.1   2680.58
# 426           8          235.93   148.00   703.44                4.3    851.44
# 114           2          189.20    96.23   185.94                5.0    282.17
# 197           6          457.49   225.75  1390.44                4.3   1616.19
# 322           4         2139.72  1626.91  2051.24                4.4   3678.15
# 134           3          393.12   228.75   493.11                4.4    721.86
# 381           4         3060.26  1983.15  4308.44                4.3   6291.59
# 12            3          335.28   170.32   494.88                4.1    665.20
# 76            6          414.05   236.80  1063.50                4.0   1300.30
# 261           4         4246.78  3324.34  3689.76                4.2   7014.10
# 449           6          303.01   178.28      inf                4.4       inf
# 179           8          182.43    94.95   699.84                3.9    794.79
# 42            1          176.14   101.25    74.89                3.8    176.14
# 56            6         4644.62  3076.12  9411.00                4.0  12487.12
# 148           2          187.05    88.03   198.04                4.3    286.07
# 9             9          423.41   231.33  1728.72                4.4   1960.05
# 229           2          200.80    80.12   241.36                4.2    321.48
# 190           5          256.57   134.25   611.60                4.9    745.85
# 26            6          247.12   153.21   563.46                4.0    716.67

# %%
df=df.drop(axis=0,index=df[df['lucro']==np.inf].index)

# %%
df.describe(include='str').T
# Out:
#           count unique           top freq
# produto     442     10  Caixa de Som   56
# categoria   442      4     Telefonia  133
# estado      442     10            ES   61
# canal       442      3   Marketplace  150

# %% [markdown]
# ## 6. Selecionando o que importa
#
# Nem toda análise precisa de todas as colunas. Vamos criar um recorte mais focado para responder perguntas de negócio.
#
# ### Questão 4
# Crie um novo DataFrame chamado `df_dash` contendo apenas as colunas:
# - `data`
# - `estado`
# - `canal`
# - `produto`
# - `categoria`
# - `vendas`
# - `lucro`
#
# Use `.copy()` para evitar problemas futuros.

# %%
cols_dashboard = ['data', 'estado', 'canal', 'produto', 'categoria', 'vendas', 'lucro']
df_dash = df[cols_dashboard].copy()
df_dash.head()
# Out:
#         data estado        canal           produto    categoria   vendas  \
# 0 2024-04-12     RJ  Marketplace       Mouse Gamer  Periféricos   562.26
# 1 2024-05-01     ES  Marketplace           Headset        Áudio  1124.08
# 2 2024-10-03     SP  Marketplace  Teclado Mecânico  Periféricos  2515.73
# 3 2024-07-06     SP  Marketplace         Webcam HD  Periféricos   596.76
# 4 2024-02-24     RJ  Loja física        Smartwatch    Telefonia  3908.08
#
#      lucro
# 0   269.16
# 1   545.00
# 2  1440.11
# 3   221.49
# 4  1243.04

# %% [markdown]
# ## 7. Preparação mínima para análise
#
# Algumas colunas podem precisar de ajuste antes de ordenar e agregar.
#
# ### Questão 5
# 1. Converta a coluna `data` para formato de data.
# 2. Crie uma coluna `mes` a partir da data.
# 3. Tente converter `vendas` para numérico, tratando possíveis textos.
# 4. Crie uma coluna chamada `vendas_num`.

# %%
df_dash['data'] = pd.to_datetime(df_dash['data'], errors='coerce')
df_dash['mes'] = df_dash['data'].dt.month_name()
df_dash['numero_mes'] = df_dash['data'].dt.month

# Limpeza simples para a coluna vendas (remove símbolo R$, espaços e troca vírgula decimal)
vendas_limpa = (
    df_dash['vendas']
    .astype(str)
    .str.replace('R$', '', regex=True)
    .str.replace('.', '', regex=False)
    .str.replace(',', '.', regex=False)
    .str.strip()
)

df_dash['vendas_num'] = pd.to_numeric(vendas_limpa, errors='coerce')
df_dash.head()
# Out:
#         data estado        canal           produto    categoria   vendas  \
# 0 2024-04-12     RJ  Marketplace       Mouse Gamer  Periféricos   562.26
# 1 2024-05-01     ES  Marketplace           Headset        Áudio  1124.08
# 2 2024-10-03     SP  Marketplace  Teclado Mecânico  Periféricos  2515.73
# 3 2024-07-06     SP  Marketplace         Webcam HD  Periféricos   596.76
# 4 2024-02-24     RJ  Loja física        Smartwatch    Telefonia  3908.08
#
#      lucro       mes  numero_mes  vendas_num
# 0   269.16     April           4       56226
# 1   545.00       May           5      112408
# 2  1440.11   October          10      251573
# 3   221.49      July           7       59676
# 4  1243.04  February           2      390808

# %% [markdown]
# ## 8. Filtragem simples: recorte de negócio
#
# Na aula, vimos o exemplo de filtrar apenas o estado do Rio de Janeiro.
#
# ### Questão 6
# Crie um DataFrame `df_rj` contendo apenas registros do estado `RJ`.
# Depois responda:
# 1. Quantos registros existem nesse recorte?
# 2. Qual a soma de vendas no RJ?

# %%
df_rj = df_dash[df_dash['estado'] == 'RJ']
df_rj.shape, df_rj['vendas_num'].sum()
# Out:
# ((35, 10), np.int64(13225948))

# %% [markdown]
# ## 9. Filtragem com múltiplas condições
#
# Agora faça um recorte mais profissional: apenas vendas do estado do RJ no canal Online.
#
# ### Questão 7
# Faça esse filtro de duas formas:
# 1. Usando operadores lógicos com `&`
# 2. Usando `query()`

# %%
df_rj_online = df_dash[(df_dash['estado'] == 'RJ') & (df_dash['canal'] == 'Online')]
df_rj_online.head()
# Out:
#           data estado   canal           produto    categoria    vendas  \
# 114 2024-10-26     RJ  Online       Mouse Gamer  Periféricos    378.40
# 173 2024-04-12     RJ  Online         Webcam HD  Periféricos    924.48
# 222 2024-12-17     RJ  Online  Teclado Mecânico  Periféricos   1996.05
# 243 2024-04-23     RJ  Online       Tablet Plus    Telefonia  10065.80
# 246 2024-06-24     RJ  Online      Smartphone X    Telefonia   8538.57
#
#        lucro       mes  numero_mes  vendas_num
# 114   185.94   October          10        3784
# 173   418.04     April           4       92448
# 222  1105.55  December          12      199605
# 243  2142.15     April           4      100658
# 246  2467.02      June           6      853857

# %%
df_rj_online_q = df_dash.query("estado == 'RJ' and canal == 'Online'")
df_rj_online_q.head()
# Out:
#           data estado   canal           produto    categoria    vendas  \
# 114 2024-10-26     RJ  Online       Mouse Gamer  Periféricos    378.40
# 173 2024-04-12     RJ  Online         Webcam HD  Periféricos    924.48
# 222 2024-12-17     RJ  Online  Teclado Mecânico  Periféricos   1996.05
# 243 2024-04-23     RJ  Online       Tablet Plus    Telefonia  10065.80
# 246 2024-06-24     RJ  Online      Smartphone X    Telefonia   8538.57
#
#        lucro       mes  numero_mes  vendas_num
# 114   185.94   October          10        3784
# 173   418.04     April           4       92448
# 222  1105.55  December          12      199605
# 243  2142.15     April           4      100658
# 246  2467.02      June           6      853857

# %% [markdown]
# ## 10. Priorização: rankings
#
# Gestores raramente leem tabelas enormes. Eles querem os **Top N**.
#
# ### Questão 8
# Gere:
# 1. Os 10 registros com maior valor de `vendas_num`
# 2. Os 10 registros com maior `lucro`
# 3. Os 5 registros com menor `lucro`
#
# Observe se aparece algum valor suspeito.

# %%
top10_vendas = df_dash.sort_values('vendas_num', ascending=False).head(10)
top10_vendas
# Out:
#           data estado        canal       produto    categoria    vendas  \
# 321 2024-08-18     SP  Loja física  Notebook Pro  Informática  36140.72
# 183 2024-12-14     ES       Online  Notebook Pro  Informática  33212.83
# 56  2024-09-06     PE       Online  Notebook Pro  Informática  27867.72
# 319 2024-05-08     SC  Marketplace  Notebook Pro  Informática  21573.95
# 132 2024-08-05     PR  Loja física  Notebook Pro  Informática  20352.96
# 387 2024-12-26     ES       Online   Tablet Plus    Telefonia  19061.82
# 74  2024-10-01     PR  Loja física  Notebook Pro  Informática  18782.88
# 245 2024-12-26     SP  Marketplace  Smartphone X    Telefonia  18417.28
# 216 2024-07-22     SC       Online  Notebook Pro  Informática  17715.88
# 368 2024-05-29     SP       Online  Smartphone X    Telefonia  17631.48
#
#         lucro        mes  numero_mes  vendas_num
# 321  10319.12     August           8     3614072
# 183  13556.90   December          12     3321283
# 56    9411.00  September           9     2786772
# 319   6869.60        May           5     2157395
# 132   8103.88     August           8     2035296
# 387   5200.11   December          12     1906182
# 74    5744.80    October          10     1878288
# 245   3773.84   December          12     1841728
# 216   5747.00       July           7     1771588
# 368   5392.08        May           5     1763148

# %%
# Primeiro garantimos que lucro esteja numérico
df_dash['lucro_num'] = pd.to_numeric(df_dash['lucro'], errors='coerce')

top10_lucro = df_dash.nlargest(10, 'lucro_num')
top10_lucro
# Out:
#           data estado        canal       produto    categoria    vendas  \
# 183 2024-12-14     ES       Online  Notebook Pro  Informática  33212.83
# 321 2024-08-18     SP  Loja física  Notebook Pro  Informática  36140.72
# 56  2024-09-06     PE       Online  Notebook Pro  Informática  27867.72
# 442 2024-02-21     PR  Loja física  Notebook Pro  Informática  19782.00
# 132 2024-08-05     PR  Loja física  Notebook Pro  Informática  20352.96
# 319 2024-05-08     SC  Marketplace  Notebook Pro  Informática  21573.95
# 110 2024-06-28     BA  Loja física  Smartphone X    Telefonia  16138.55
# 109 2024-09-20     PE  Marketplace   Tablet Plus    Telefonia  14602.02
# 216 2024-07-22     SC       Online  Notebook Pro  Informática  17715.88
# 74  2024-10-01     PR  Loja física  Notebook Pro  Informática  18782.88
#
#         lucro        mes  numero_mes  vendas_num  lucro_num
# 183  13556.90   December          12     3321283   13556.90
# 321  10319.12     August           8     3614072   10319.12
# 56    9411.00  September           9     2786772    9411.00
# 442   8546.28   February           2      197820    8546.28
# 132   8103.88     August           8     2035296    8103.88
# 319   6869.60        May           5     2157395    6869.60
# 110   6519.65       June           6     1613855    6519.65
# 109   6151.92  September           9     1460202    6151.92
# 216   5747.00       July           7     1771588    5747.00
# 74    5744.80    October          10     1878288    5744.80

# %%
bottom5_lucro = df_dash.nsmallest(5, 'lucro_num')
bottom5_lucro
# Out:
#           data estado        canal      produto    categoria  vendas  lucro  \
# 415 2024-10-11     MG  Loja física  Mouse Gamer  Periféricos  158.60  60.58
# 273 2024-09-15     ES       Online  Mouse Gamer  Periféricos  160.85  65.92
# 48  2024-10-31     GO       Online  Mouse Gamer  Periféricos  175.18  71.29
# 42  2024-09-12     RJ  Loja física  Mouse Gamer  Periféricos  176.14  74.89
# 143 2024-05-20     SC  Marketplace    Webcam HD  Periféricos  203.30  77.72
#
#            mes  numero_mes  vendas_num  lucro_num
# 415    October          10        1586      60.58
# 273  September           9       16085      65.92
# 48     October          10       17518      71.29
# 42   September           9       17614      74.89
# 143        May           5        2033      77.72

# %% [markdown]
# ## 11. Ranking por produto
#
# Agora vamos sair do nível do registro e pensar em **resultado por produto**.
#
# ### Questão 9
# Agrupe por produto e calcule:
# - soma de vendas
# - soma de lucro
#
# Depois:
# 1. Mostre os 10 produtos mais lucrativos
# 2. Interprete o resultado em linguagem de negócio

# %%
ranking_produtos = (
    df_dash.groupby('produto', dropna=False)
    .agg(
        vendas_total=('vendas_num', 'sum'),
        lucro_total=('lucro_num', 'sum')
    )
    .sort_values('lucro_total', ascending=False)
)

ranking_produtos.head(10)
# Out:
#                   vendas_total  lucro_total
# produto
# Notebook Pro          37921671    135237.36
# Smartphone X          33625813     94603.87
# Tablet Plus           28875008     90646.58
# Monitor 27            14780460     67019.52
# Smartwatch            14826521     65393.66
# Caixa de Som           7102942     37746.91
# Teclado Mecânico       4878506     24548.13
# Headset                4614250     24360.41
# Mouse Gamer            2419618     15472.38
# Webcam HD              2488574     14672.55

# %% [markdown]
# ## 12. Ranking por estado e canal
#
# ### Questão 10
# Crie dois rankings:
# 1. Estados com maior receita total
# 2. Canais com maior lucro total
#
# Depois escreva uma interpretação curta para cada ranking.

# %%
ranking_estados = (
    df_dash.groupby('estado', dropna=False)['vendas_num']
    .sum()
    .sort_values(ascending=False)
)

ranking_canais = (
    df_dash.groupby('canal', dropna=False)['lucro_num']
    .sum()
    .sort_values(ascending=False)
)

ranking_estados, ranking_canais
# Out:
# (estado
#  SP    23220604
#  BA    20158371
#  PE    18892544
#  ES    18495206
#  GO    14113942
#  PR    13521454
#  RJ    13225948
#  SC    11724060
#  MG     9847282
#  RS     8333952
#  Name: vendas_num, dtype: int64,
#  canal
#  Online         205586.74
#  Loja física    184811.86
#  Marketplace    179302.77
#  Name: lucro_num, dtype: float64)

# %% [markdown]
# ## 13. Análise temporal simples
#
# ### Questão 11
# Agrupe os dados por `mes` e calcule a receita total mensal.
# Depois responda:
# 1. Há meses de maior desempenho? R: Sim, Maio e Dezembro
# 2. Existe indício de sazonalidade? R: Nao

# %%
receita_mensal = (
    df_dash.groupby(['mes','numero_mes'],as_index=False)['lucro_num']
    .sum()
    .sort_values(by='numero_mes',ascending=True)
)
receita_mensal
# Out:
#           mes  numero_mes  lucro_num
# 4     January           1   35493.83
# 3    February           2   59537.20
# 7       March           3   37036.16
# 0       April           4   43350.51
# 8         May           5   57699.05
# 6        June           6   55572.64
# 5        July           7   28671.45
# 1      August           8   48993.07
# 11  September           9   56034.56
# 10    October          10   34006.49
# 9    November          11   44741.98
# 2    December          12   68564.43

# %%
plt.figure(figsize=(14,8))
plt.plot('mes','lucro_num',data=receita_mensal,marker='o', color='C2')
plt.title('Lucro mensal ao longo do ano')

plt.show()

# %% [markdown]
# ## 14. A última milha: interpretação
#
# Na aula, vimos que um analista não entrega apenas tabela — entrega **decisão**.
#
# ### Questão 12
# Com base nos resultados do notebook, escreva interpretações gerenciais para:
# 1. O produto mais lucrativo R: Notebook Pro
# 2. O estado com maior receita R: SP
# 3. O canal com maior lucro R: Loja Fisica
# 4. Um possível problema de qualidade encontrado
# R: Categorias Marktplaze e online duplicados

# %%
df.groupby('canal')['receita'].sum().plot.barh(title='Receita por canal',color='C2');

# %% [markdown]
# ## 15. Desafio extra (opcional)
#
# Faça uma limpeza adicional do dataset:
# - padronize valores de `canal` (`online`, `ONLINE`, `MarketPlace`, etc.)
# - padronize `estado` (`rj` -> `RJ`)
# - substitua infinitos em `lucro_num` por `NaN`
# - trate valores ausentes como julgar adequado
#
# Depois gere novamente os rankings e compare os resultados.

# %% [markdown]
#  *Ja foi feito ao longo da análise do dataset*

# %% [markdown]
# ## 16. Entrega esperada
#
# Seu notebook deve demonstrar:
# - organização
# - comentários explicativos
# - código legível
# - interpretação de negócio
#
# ### Fechamento
# Ao terminar, salve o notebook com suas respostas e envie junto com o arquivo CSV utilizado.
